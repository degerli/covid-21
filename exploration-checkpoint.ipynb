# %%
# resources
# https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_outbreak_in_Mainland_China
# https://en.wikipedia.org/wiki/2020_coronavirus_outbreak_in_Japan
# https://en.wikipedia.org/wiki/2020_coronavirus_outbreak_in_South_Korea
# https://en.wikipedia.org/wiki/2020_coronavirus_outbreak_in_Italy
# https://en.wikipedia.org/wiki/2020_coronavirus_outbreak_in_Iran

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Load data
df = pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#          Date  China  Japan  Korea  Italy  Iran  Germany  US  Sweden  Spain  \
# 0  2020-01-16   45.0    NaN    NaN    NaN   NaN      NaN NaN     NaN    NaN
# 1  2020-01-17   62.0    NaN    NaN    NaN   NaN      NaN NaN     NaN    NaN
# 2  2020-01-18  121.0    NaN    NaN    NaN   NaN      NaN NaN     NaN    NaN
# 3  2020-01-19  198.0    NaN    NaN    NaN   NaN      NaN NaN     NaN    NaN
# 4  2020-01-20  291.0    NaN    1.0    NaN   NaN      NaN NaN     NaN    NaN
#
#    Netherlands  France  UK
# 0          NaN     NaN NaN
# 1          NaN     NaN NaN
# 2          NaN     NaN NaN
# 3          NaN     NaN NaN
# 4          NaN     NaN NaN

# %%
df
# Out:
#           Date    China  Japan   Korea   Italy    Iran  Germany     US  \
# 0   2020-01-16     45.0    NaN     NaN     NaN     NaN      NaN    NaN
# 1   2020-01-17     62.0    NaN     NaN     NaN     NaN      NaN    NaN
# 2   2020-01-18    121.0    NaN     NaN     NaN     NaN      NaN    NaN
# 3   2020-01-19    198.0    NaN     NaN     NaN     NaN      NaN    NaN
# 4   2020-01-20    291.0    NaN     1.0     NaN     NaN      NaN    NaN
# 5   2020-01-21    440.0    NaN     1.0     NaN     NaN      NaN    1.0
# 6   2020-01-22    571.0    NaN     1.0     NaN     NaN      NaN    NaN
# 7   2020-01-23    830.0    1.0     1.0     NaN     NaN      NaN    NaN
# 8   2020-01-24   1287.0    2.0     2.0     NaN     NaN      NaN    NaN
# 9   2020-01-25   1975.0    3.0     2.0     NaN     NaN      NaN    2.0
# 10  2020-01-26   2744.0    4.0     3.0     NaN     NaN      NaN    4.0
# 11  2020-01-27   4515.0    4.0     4.0     NaN     NaN      1.0    NaN
# 12  2020-01-28   5974.0    7.0     4.0     NaN     NaN      4.0    NaN
# 13  2020-01-29   7711.0    8.0     4.0     NaN     NaN      NaN    NaN
# 14  2020-01-30   9692.0   14.0     6.0     NaN     NaN      5.0    5.0
# 15  2020-01-31  11791.0   17.0    11.0     2.0     NaN      6.0    6.0
# 16  2020-02-01  14380.0   20.0    12.0     NaN     NaN      7.0    7.0
# 17  2020-02-02  17205.0   20.0    15.0     NaN     NaN      NaN   10.0
# 18  2020-02-03  20438.0   20.0    15.0     NaN     NaN      9.0    NaN
# 19  2020-02-04  24324.0   23.0    16.0     NaN     NaN      NaN    NaN
# 20  2020-02-05  28018.0   25.0    19.0     NaN     NaN      NaN   11.0
# 21  2020-02-06  31161.0   25.0    23.0     3.0     NaN     10.0    NaN
# 22  2020-02-07  34546.0   25.0    24.0     NaN     NaN     12.0    NaN
# 23  2020-02-08  37198.0   26.0    24.0     NaN     NaN      NaN    NaN
# 24  2020-02-09  40171.0   26.0    27.0     NaN     NaN      NaN    NaN
# 25  2020-02-10  48315.0   26.0    27.0     NaN     NaN      NaN    NaN
# 26  2020-02-11  55220.0   28.0    28.0     NaN     NaN     14.0    NaN
# 27  2020-02-12  58761.0   29.0    28.0     NaN     NaN      NaN    NaN
# 28  2020-02-13  63851.0   33.0    28.0     NaN     NaN      NaN    NaN
# 29  2020-02-14  66492.0   41.0    28.0     NaN     NaN      NaN    NaN
# 30  2020-02-15  68500.0   53.0    28.0     NaN     NaN      NaN    NaN
# 31  2020-02-16  70548.0   59.0    29.0     NaN     NaN      NaN    NaN
# 32  2020-02-17  72436.0   66.0    30.0     NaN     NaN      NaN    NaN
# 33  2020-02-18  74185.0   74.0    31.0     NaN     NaN      NaN    NaN
# 34  2020-02-19  75003.0   84.0    51.0     NaN     2.0      NaN    NaN
# 35  2020-02-20  75891.0   94.0   104.0     NaN     5.0      NaN   13.0
# 36  2020-02-21  76288.0  109.0   204.0    20.0    18.0      NaN    NaN
# 37  2020-02-22  76936.0  135.0   433.0    79.0    28.0      NaN    NaN
# 38  2020-02-23  77150.0  147.0   602.0   150.0    43.0      NaN    NaN
# 39  2020-02-24  77658.0  160.0   833.0   227.0    61.0     16.0    NaN
# 40  2020-02-25  78064.0  171.0   977.0   320.0    95.0     18.0    NaN
# 41  2020-02-26  78497.0  189.0  1261.0   398.0   139.0     21.0   14.0
# 42  2020-02-27  78824.0  214.0  1766.0   650.0   245.0     26.0    NaN
# 43  2020-02-28  79251.0  233.0  2337.0   888.0   388.0     53.0   24.0
# 44  2020-02-29  79824.0  242.0  3150.0  1128.0   593.0     66.0    NaN
# 45  2020-03-01  80026.0  265.0  4212.0  1694.0   978.0    117.0   42.0
# 46  2020-03-02  80151.0  280.0  4812.0  2036.0  1501.0    155.0   57.0
# 47  2020-03-03  80270.0  294.0  5328.0  2502.0  2336.0    196.0   85.0
# 48  2020-03-04  80409.0  310.0  5766.0  3089.0  2922.0    240.0  112.0
# 49  2020-03-05  80552.0  331.0  6284.0  3858.0  3513.0    349.0  175.0
# 50  2020-03-06      NaN    NaN  6593.0  4636.0  4747.0    534.0  227.0
# 51  2020-03-07      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 52  2020-03-08      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 53  2020-03-09      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 54  2020-03-10      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 55  2020-03-11      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 56  2020-03-12      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 57  2020-03-13      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 58  2020-03-14      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 59  2020-03-15      NaN    NaN     NaN     NaN     NaN      NaN    NaN
#
#     Sweden  Spain  Netherlands  France     UK
# 0      NaN    NaN          NaN     NaN    NaN
# 1      NaN    NaN          NaN     NaN    NaN
# 2      NaN    NaN          NaN     NaN    NaN
# 3      NaN    NaN          NaN     NaN    NaN
# 4      NaN    NaN          NaN     NaN    NaN
# 5      NaN    NaN          NaN     NaN    NaN
# 6      NaN    NaN          NaN     NaN    NaN
# 7      NaN    NaN          NaN     NaN    NaN
# 8      NaN    NaN          NaN     NaN    NaN
# 9      NaN    NaN          NaN     NaN    NaN
# 10     NaN    NaN          NaN     NaN    NaN
# 11     NaN    NaN          NaN     NaN    NaN
# 12     NaN    NaN          NaN     NaN    NaN
# 13     NaN    NaN          NaN     NaN    NaN
# 14     NaN    NaN          NaN     NaN    NaN
# 15     1.0    NaN          NaN     NaN    2.0
# 16     NaN    NaN          NaN     NaN    NaN
# 17     NaN    NaN          NaN     NaN    NaN
# 18     NaN    NaN          NaN     NaN    NaN
# 19     NaN    NaN          NaN     NaN    NaN
# 20     NaN    NaN          NaN     NaN    NaN
# 21     NaN    NaN          NaN     NaN    3.0
# 22     NaN    NaN          NaN     NaN    NaN
# 23     NaN    NaN          NaN     NaN    NaN
# 24     NaN    NaN          NaN     NaN    NaN
# 25     NaN    NaN          NaN     NaN    7.0
# 26     NaN    NaN          NaN     NaN    7.0
# 27     NaN    NaN          NaN     NaN    8.0
# 28     NaN    NaN          NaN     NaN    NaN
# 29     NaN    NaN          NaN     NaN    NaN
# 30     NaN    NaN          NaN     NaN    NaN
# 31     NaN    NaN          NaN     NaN    NaN
# 32     NaN    NaN          NaN     NaN    NaN
# 33     NaN    NaN          NaN     NaN    NaN
# 34     NaN    NaN          NaN     NaN    NaN
# 35     NaN    NaN          NaN     NaN    NaN
# 36     NaN    NaN          NaN     NaN    NaN
# 37     NaN    NaN          NaN     NaN    NaN
# 38     NaN    NaN          NaN     NaN   12.0
# 39     NaN    NaN          NaN     NaN    NaN
# 40     NaN    8.0          NaN    13.0    NaN
# 41     2.0   14.0          NaN    18.0    NaN
# 42     7.0   26.0          1.0    38.0   15.0
# 43    11.0   45.0          2.0    57.0   20.0
# 44    13.0   59.0          6.0   100.0   21.0
# 45    14.0   84.0          9.0   130.0   35.0
# 46    15.0  125.0         19.0   191.0   39.0
# 47    30.0  169.0         23.0   212.0   51.0
# 48    52.0  228.0         38.0   285.0   85.0
# 49    94.0  282.0         82.0   423.0  115.0
# 50   137.0  401.0        128.0   613.0  163.0
# 51     NaN    NaN          NaN     NaN    NaN
# 52     NaN    NaN          NaN     NaN    NaN
# 53     NaN    NaN          NaN     NaN    NaN
# 54     NaN    NaN          NaN     NaN    NaN
# 55     NaN    NaN          NaN     NaN    NaN
# 56     NaN    NaN          NaN     NaN    NaN
# 57     NaN    NaN          NaN     NaN    NaN
# 58     NaN    NaN          NaN     NaN    NaN
# 59     NaN    NaN          NaN     NaN    NaN

# %%
cols = df.drop(columns=['Date']).keys()
print(cols)
# Out:
# Index([u'China', u'Japan', u'Korea', u'Italy', u'Iran', u'Germany', u'US',
#        u'Sweden', u'Spain', u'Netherlands', u'France', u'UK'],
#       dtype='object')

# %%
pop = {
    'China':1.386,
    'Japan':0.126,
    'Korea':0.051,
    'Italy':0.060,
    'Iran':0.082,
    'Germany':0.082, 
    'US':0.327, 
    'Sweden':0.010,
    'Spain': 0.046,
    'Netherlands': 0.017,
    'France': 0.067,
    'UK': 0.066,
}

# %%
def m1(t, a, b):
    return a*np.exp(b*t)

# %%
def m2(t, a, b, c):
    return a*np.exp(b*t)/(1+c*np.exp(b*t))

# %%
offset = {
    'China':10,
    'Japan':25,
    'Korea':40,
    'Italy':40,
    'Iran':40,
    'Germany':40, 
    'US':44, 
    'Sweden':45,
    'Spain': 41,
    'Netherlands': 45,
    'France': 45,
    'UK': 45,
}

# %%
cols = df.drop(columns=['Date', 'Germany', 'France']).keys()
plt.figure(figsize=(20, 16))
popt = {}
df_pred = df.copy()
df_pred = df_pred.iloc[48:]
for ic, c in enumerate(cols):
    print(c)
    plt.subplot(np.ceil(cols.shape[0]/3), 4, ic+1)
    df_tmp = df.copy()
    df_tmp = df_tmp[['Date', c]].dropna()
    df_tmp = df_tmp.loc[df_tmp.index > offset[c]]
    df_tmp.index = df_tmp.index-df_tmp.index[0]
    t = np.arange(0, 40)
    popt[c], pcov = curve_fit(m2, df_tmp.index, df_tmp[c])
    y = m2(t, popt[c][0], popt[c][1], popt[c][2])
    y_pred = m2(df_pred[c].index-offset[c]-1, popt[c][0], popt[c][1], popt[c][2])
    df_pred[c] = np.ceil(y_pred)
    #print(popt[c])
    plt.plot(t, y, '-r', linewidth=4, label='Model Fit')
    plt.plot(df_tmp['Date'], df_tmp[c], '.b', markersize=10, label='Data')
    #plt.plot(df_pred[c].index-offset[c]-1, y_pred, '*c', markersize=10, label='Prediction')
    plt.title(c)
    plt.xticks(df_tmp['Date'].values[::4], rotation=20)
    plt.yscale('log')
    plt.grid()
    plt.legend()
plt.savefig('figs/wuhan_master.png')
# Out:
# China
# Japan
# Korea
# Italy
# Iran
# US
# Sweden
# Spain
# Netherlands
# UK

# %%
[(c,popt[c][0]) for c in popt.keys()]
# Out:
# [('Korea', 1485.705488786581),
#  ('Italy', 519.4540160166086),
#  ('US', 41.2551022638204),
#  ('Sweden', 15.35679894694996),
#  ('Netherlands', 13.475744351105233),
#  ('China', 5057.830297820168),
#  ('UK', 39.51256884202152),
#  ('Iran', 176.12570990728528),
#  ('Japan', 28.441464436606065),
#  ('Spain', 32.84216393584983)]

# %%
df_pred.drop(columns=['Germany', 'Netherlands', 'France']).to_csv('Predictions_of_infected_2020-March-05.csv')

# %%
df_pred
# Out:
#           Date    China  Japan   Korea   Italy    Iran  Germany     US  \
# 48  2020-03-04  80187.0  313.0  5902.0  3166.0  2909.0    240.0  120.0
# 49  2020-03-05  80237.0  327.0  6265.0  3865.0  3770.0    349.0  168.0
# 50  2020-03-06  80277.0  339.0  6518.0  4607.0  4625.0    534.0  229.0
# 51  2020-03-07  80308.0  351.0  6688.0  5357.0  5386.0      NaN  303.0
# 52  2020-03-08  80333.0  362.0  6799.0  6078.0  6003.0      NaN  384.0
# 53  2020-03-09  80353.0  371.0  6872.0  6740.0  6465.0      NaN  468.0
# 54  2020-03-10  80369.0  379.0  6918.0  7322.0  6791.0      NaN  548.0
# 55  2020-03-11  80381.0  387.0  6948.0  7814.0  7012.0      NaN  618.0
# 56  2020-03-12  80391.0  393.0  6966.0  8216.0  7157.0      NaN  676.0
# 57  2020-03-13  80399.0  399.0  6978.0  8537.0  7250.0      NaN  720.0
# 58  2020-03-14  80405.0  404.0  6986.0  8786.0  7310.0      NaN  753.0
# 59  2020-03-15  80410.0  408.0  6991.0  8978.0  7348.0      NaN  777.0
#
#     Sweden   Spain  Netherlands  France     UK
# 48    55.0   222.0         45.0   285.0   82.0
# 49    93.0   298.0         78.0   423.0  117.0
# 50   138.0   396.0        129.0   613.0  163.0
# 51   178.0   516.0        198.0     NaN  220.0
# 52   206.0   660.0        276.0     NaN  284.0
# 53   223.0   824.0        347.0     NaN  350.0
# 54   232.0  1003.0        402.0     NaN  413.0
# 55   236.0  1186.0        438.0     NaN  468.0
# 56   238.0  1364.0        460.0     NaN  512.0
# 57   239.0  1528.0        473.0     NaN  545.0
# 58   239.0  1672.0        480.0     NaN  569.0
# 59   239.0  1792.0        484.0     NaN  586.0

# %%
c = 'Italy'
df_pred = df.copy()
df_pred = df_pred.iloc[48:]

# %%
df_pred
# Out:
#           Date    China  Japan   Korea   Italy    Iran  Germany     US  \
# 48  2020-03-04  80409.0  310.0  5766.0  3089.0  2922.0    240.0  112.0
# 49  2020-03-05  80552.0  331.0  6284.0  3858.0  3513.0    349.0  175.0
# 50  2020-03-06      NaN    NaN  6593.0  4636.0  4747.0    534.0  227.0
# 51  2020-03-07      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 52  2020-03-08      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 53  2020-03-09      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 54  2020-03-10      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 55  2020-03-11      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 56  2020-03-12      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 57  2020-03-13      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 58  2020-03-14      NaN    NaN     NaN     NaN     NaN      NaN    NaN
# 59  2020-03-15      NaN    NaN     NaN     NaN     NaN      NaN    NaN
#
#     Sweden  Spain  Netherlands  France     UK
# 48    52.0  228.0         38.0   285.0   85.0
# 49    94.0  282.0         82.0   423.0  115.0
# 50   137.0  401.0        128.0   613.0  163.0
# 51     NaN    NaN          NaN     NaN    NaN
# 52     NaN    NaN          NaN     NaN    NaN
# 53     NaN    NaN          NaN     NaN    NaN
# 54     NaN    NaN          NaN     NaN    NaN
# 55     NaN    NaN          NaN     NaN    NaN
# 56     NaN    NaN          NaN     NaN    NaN
# 57     NaN    NaN          NaN     NaN    NaN
# 58     NaN    NaN          NaN     NaN    NaN
# 59     NaN    NaN          NaN     NaN    NaN

# %%
c = 'Korea'
plt.figure(figsize=(16, 8))
popt = {}
print(c)
df_tmp = df.copy()
df_tmp = df_tmp[['Date', c]].dropna()
df_tmp = df_tmp.loc[df_tmp.index > offset[c]]
df_tmp.index = df_tmp.index-df_tmp.index[0]
t = np.arange(0, 40)
popt[c], pcov = curve_fit(m2, df_tmp.index, df_tmp[c])
y = m2(t, popt[c][0], popt[c][1], popt[c][2])
y_pred = m2(df_pred[c].index-offset[c]-1, popt[c][0], popt[c][1], popt[c][2])
df_pred[c] = np.ceil(y_pred)
#print(popt[c])
plt.plot(t, y, '-r', linewidth=4, label='Prediction')
plt.plot(df_tmp['Date'], df_tmp[c], '.b', markersize=20, label='People Infected')
plt.plot(df_pred['Date'], df_pred[c], '.r', markersize=1)
#plt.plot(df_pred[c].index-offset[c]-1, y_pred, '*c', markersize=10, label='Prediction')
plt.title(c)
plt.xticks(df_pred['Date'].values[::4], rotation=20)
#plt.yscale('log')
plt.grid()
plt.xlabel('Date')
plt.ylabel('Number of people infected')
plt.legend()
plt.savefig('figs/'+c+'.png')
# Out:
# Korea
