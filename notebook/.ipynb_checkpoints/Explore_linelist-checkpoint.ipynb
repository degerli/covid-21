# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
import seaborn as sns
import matplotlib.pyplot as plt
cmap = plt.get_cmap('jet_r')
import matplotlib.dates as mdates
import warnings
warnings.filterwarnings('ignore')
from scipy.optimize import curve_fit
import folium
import branca
# %matplotlib inline

# %%
df_line = pd.read_csv('../input/COVID19_open_line_list.csv')

# %%
pd.DataFrame(df_line['country'].value_counts()).T
# Out:
#          China  South Korea  Japan  Italy  Singapore  Thailand  Iran  Kuwait  \
# country  10446          938    731    588         91        40    28      26
#
#          United Arab Emirates  Bahrain  Germany  France  Malaysia  \
# country                    20       20       20      19        17
#
#          United States  Vietnam  Australia  Spain  United Kingdom  Canada  \
# country             17       16         15     13              12      10
#
#          Switzerland  Sweden  Oman  Iraq  Norway  Israel  Philippines  \
# country           10       9     6     6       4       4            3
#
#          Croatia  Romania  Lebanon  India  Austria  Russia  Pakistan  Finland  \
# country        3        3        3      3        2       2         2        2
#
#          Georgia  Netherlands  Nigeria  Algeria  Sri Lanka  Lithuania  Egypt  \
# country        2            2        1        1          1          1      1
#
#          San Marino  Nepal  Estonia  Greece  Belgium  Ecuador  \
# country           1      1        1       1        1        1
#
#          North Macedonia  Brazil  Cambodia  Afghanistan
# country                1       1         1            1

# %%
df_line.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44'],
#       dtype='object')

# %%
pd.DataFrame(df_line['symptoms'].value_counts()).T
# Out:
#           fever  cough, fever  pneumonitis  cough  pneumonia  asymptomatic  \
# symptoms    131            55           19     15          7             6
#
#           fever, cough  fever (38 ° C)  cough, sore throat  \
# symptoms             6               4                   4
#
#           cough, fever, runny nose  cough, fatigue, fever  fever 38  \
# symptoms                         4                      3         3
#
#           fever; fatigue  fever, sore throat  discomfort  \
# symptoms               3                   3           3
#
#           cough, fever, shortness of breath  cough, fever, sore throat  \
# symptoms                                  3                          3
#
#           fatigue, fever  fever, cough, phlegm  cough, fever, sputum  \
# symptoms               3                     2                     2
#
#           nausea, vomiting  fever 37.7℃  fever, headache  \
# symptoms                 2            2                2
#
#           fever, respiratory symptoms  fever, weak  flu-like symptoms  \
# symptoms                            2            2                  2
#
#           chills, fever  dry cough  cough, runny nose  mild  fever; cough  \
# symptoms              2          2                  2     2             2
#
#           acute respiratory viral infection, fever  \
# symptoms                                         2
#
#           fever, sore muscle, weakness  fever, runny nose  \
# symptoms                             2                  2
#
#           cough; sputum; fever  respiratory symptoms  \
# symptoms                     2                     2
#
#           fever, cough, phlegm, dyspnea  chills, fever, headache, sore throat  \
# symptoms                              2                                     1
#
#           fever 37.5 , headache, malaise  \
# symptoms                               1
#
#           chills, fever, runny nose, sore throat, wheezing  \
# symptoms                                                 1
#
#           fever (37.4 ℃), cough  chills, fever, myalgias, sore throat  \
# symptoms                      1                                     1
#
#           fever, headache, runny nose  fever, myalgia  \
# symptoms                            1               1
#
#           chills, fever, muscle aches, other symptoms  fever, sneeze  \
# symptoms                                            1              1
#
#           cough, dyspnea, fever  fever 38.2 ℃, cough  \
# symptoms                      1                    1
#
#           fever, joint pain, pneumonia  Fever (37.4 ° C), malaise, sore throa  \
# symptoms                             1                                      1
#
#           fever, severe pneumonia  weakness  \
# symptoms                        1         1
#
#           cough, fever, pneumonia, respiratory distress  \
# symptoms                                              1
#
#           fever (37 ℃), breathing difficulty  fever, pharyngeal discomfort  \
# symptoms                                   1                             1
#
#           chills, conjunctivitis, cough, fever  cough, fever, nausea  \
# symptoms                                     1                     1
#
#           fever (38.3 ℃)  fever, pneumonia, sore throat  \
# symptoms               1                              1
#
#           no respiratory symptoms, esophageal reflux  fever (37.5 ℃ ～ 38.0 ℃)  \
# symptoms                                           1                        1
#
#           chills, cough, joint pain  systemic weakness, runny nose, fever  \
# symptoms                          1                                     1
#
#           no serious symptoms  cough, discomfort, fever, other symptoms  \
# symptoms                    1                                         1
#
#           fatigue, fever, weakness  fatigue, muscle aches, sore throat  \
# symptoms                         1                                   1
#
#           fever (37.0 ℃), fever (38.7 ℃)  \
# symptoms                               1
#
#           abdominal pain, pulmonary inflammation  cough, high fever, myalgia  \
# symptoms                                       1                           1
#
#           fever, full body slump  nausea  cough, fever, myalgia  \
# symptoms                       1       1                      1
#
#           cough, fever, malaise  low fever (37.4 ℃)  \
# symptoms                      1                   1
#
#           cough, diarrhoea, runny nose  fever; cough; fatigue; nausea  \
# symptoms                             1                              1
#
#           coughing, fever, muscle aches  Fever (38 ° C)  runny nose  \
# symptoms                              1               1           1
#
#           fever (37.5 ℃, then 38 ℃), cough, malaise  \
# symptoms                                          1
#
#           cough, sore throat, sputum  chest tightness  cough; fever  fatigue  \
# symptoms                           1                1             1        1
#
#           fever (37.4 ° C), pneumonia  cough, chest tightness, dry mouth  \
# symptoms                            1                                  1
#
#           dyspnea, fever  dry throat; dry cough  \
# symptoms               1                      1
#
#           chest distress, cough, expectoration, muscular soreness  \
# symptoms                                                  1
#
#           vomiting, cough, fever (38.2 ℃), sore throat  \
# symptoms                                             1
#
#           fever, shortness of breath, pneumonia  \
# symptoms                                      1
#
#           Sputum, cough symptoms, fever (37 ℃), cough, breathing difficulty  \
# symptoms                                                  1
#
#           cough; throat discomfort  chest tightness; fatigue  \
# symptoms                         1                         1
#
#           nausea, cough, pneumonia, fever  cough, dizziness  \
# symptoms                                1                 1
#
#           dry throat; sore throat; fatigue  cough, fever, soreness  \
# symptoms                                 1                       1
#
#           chills, diarrhea, dyspnea, headache, lack of energy, muscle pain  \
# symptoms                                                  1
#
#           chills, cough, fever  chest distress, dyspnea  \
# symptoms                     1                        1
#
#           sore throat, fever (38-39 ℃)  cough, fever, weakness  \
# symptoms                             1                       1
#
#           fever; fatigue; dry cough  fever 37.5℃  cough, expectoration, fever  \
# symptoms                          1            1                            1
#
#           fever, muscular soreness, rigor  Sore throat  fever 38.3 ℃ , cough  \
# symptoms                                1            1                     1
#
#           cough, dyspnea  \
# symptoms               1
#
#           malaise, fever (37 ℃); headache, toothache, pneumonia  \
# symptoms                                                  1
#
#           cough, fever, pneumonia  sore throat  Fever, cough, headache  \
# symptoms                        1            1                       1
#
#           lesions on chest radiographs  myalgia, rhinorrhea  \
# symptoms                             1                    1
#
#           fever (39 ° C), joint pain  \
# symptoms                           1
#
#           fever (38.0 ℃), Fatigue, difficulty walking  pharyngeal discomfort  \
# symptoms                                            1                      1
#
#           low fever (37.2 ° C); cough  \
# symptoms                            1
#
#           fever (40.3 ℃), Headache, malaise, joint pain  Cough, fever (38 ℃)  \
# symptoms                                              1                    1
#
#           Pharyngeal dryness  fever (39.5 ℃)  cough, fever, shortness breath  \
# symptoms                   1               1                               1
#
#           cough, fever, eventually showed acute left heart failure and acute coronary syndrome  \
# symptoms                                                  1
#
#           fever; runny nose  fever 37 C  pharynx  \
# symptoms                  1           1        1
#
#           sore throat, Cough, fever (37 ℃)  chills, headache, fever  \
# symptoms                                 1                        1
#
#           no symptoms  aching muscles, fever, pneumonia  fever 37.2  \
# symptoms            1                                 1           1
#
#           transient fatigue  diarrhea  fever 37.1 ℃ , couh  chills, fatigue  \
# symptoms                  1         1                    1                1
#
#           cough, fatigue, fever, sputum  cough, malaise  cough, sputum  \
# symptoms                              1               1              1
#
#           discomfort, fever  cough, fever, myalgia, rhinorrhea, sore throat  \
# symptoms                  1                                               1
#
#           similar to a respiratory infection  fever 39.0 ℃  \
# symptoms                                   1             1
#
#           cough, diarrheoa, vomiting  difficulty breathing  \
# symptoms                           1                     1
#
#           eye irritation, fever  \
# symptoms                      1
#
#           cough, diarrhea, fever, rhinorrhoea, sneezing  \
# symptoms                                              1
#
#           fever 38.1 ℃ Cough, malaise, anorexia  headache; dry mouth  \
# symptoms                                      1                    1
#
#           cough, headache  physical discomfort  \
# symptoms                1                    1
#
#           sore throat; fever, nasal discharge  \
# symptoms                                    1
#
#           cough, fatigue, fever, weakness  \
# symptoms                                1
#
#           fever; dry mouth; throat discomfort  severe dyspnea  fever (38.0 ℃)  \
# symptoms                                    1               1               1
#
#           fever (39.9 ℃), cough  \
# symptoms                      1
#
#           cough, fever, headache, muscular soreness, weak  yes  \
# symptoms                                                1    1
#
#           Discharge, cough, sore throat, chest pain  malaise, headache  \
# symptoms                                          1                  1
#
#           Fever (38.1 ° C), cough, headache.  chest tightness, fever  \
# symptoms                                   1                       1
#
#           fever (39.5 ℃), malaise  chest pain, nasal congestion  \
# symptoms                        1                             1
#
#           fever, dry throat, sore throat  cough, respiratory problems  \
# symptoms                               1                            1
#
#           abdominal pain, diarrhea, fever, general malaise  \
# symptoms                                                 1
#
#           cough, difficulty breathing, fever  dizziness, sore limbs  \
# symptoms                                   1                      1
#
#           diarrhea, fever, nasal congestion, pleuritic chest pain, sore throat  \
# symptoms                                                  1
#
#           fever, pharyngalgia  chest pain, cough  Sore throat, chills  \
# symptoms                    1                  1                    1
#
#           fever 39.3  cough, muscle soreness, sweating  anorexia  \
# symptoms           1                                 1         1
#
#           fever, myalgia, shortness of breath  \
# symptoms                                    1
#
#           chest tightness, dyspnea, fever  chills,  fever (38 ℃), malaise  \
# symptoms                                1                               1
#
#           fever 38.3  muscular soreness  37.1 ° C, mild coughing  \
# symptoms           1                  1                        1
#
#           poor physical condition  fatigue, fever (38 ℃)  \
# symptoms                        1                      1
#
#           fever (38-39 ° C), malaise  fever; dry cough; fatigue  \
# symptoms                           1                          1
#
#           fever, sore throat, mild cough  fever; sore throat;fatigue;vomiting  \
# symptoms                               1                                    1
#
#           cough, phlegm, fever 37 degrees  chills, headache, fatigue  \
# symptoms                                1                          1
#
#           fever, joint pain, muscle soreness  fever, sore throat, sputum  \
# symptoms                                   1                           1
#
#           fever (37.8 ℃), cough  rever, cough  \
# symptoms                      1             1
#
#           cough, fever (38.3 ℃), joint pain  acute pharyngitis  \
# symptoms                                  1                  1
#
#           anorexia, fatigue  cough, muscular stiffness, weak  \
# symptoms                  1                                1
#
#           cough, fever, muscular soreness  chills, cough, fatigue, fever  \
# symptoms                                1                              1
#
#           cough, shortness of breath  \
# symptoms                           1
#
#           anhelation, cough, fever, pleural effusion, weakness  \
# symptoms                                                  1
#
#           low fever 37.0 ℃  fever and cough  \
# symptoms                 1                1
#
#           fever; nasal congestion; runny nose; sore throat; cough  \
# symptoms                                                  1
#
#           cough, fever, muscle ache  fatigue, fever, headache  \
# symptoms                          1                         1
#
#           fever 37.8 ℃ , sore throat  fever (39.3 ℃), cough  \
# symptoms                           1                      1
#
#           feeling ill, coughing  cough; sore body; cold  \
# symptoms                      1                       1
#
#           chest tightness, fever, nausea  fever;sore throat; fatigue; diarrhea
# symptoms                               1                                     1
